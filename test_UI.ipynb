# %%
import tkinter as tk
from PIL import Image, ImageTk
import cv2

class App:
    def __init__(self):
        self.threshold = 80.0
        
        self.root = tk.Tk()
        self.root.geometry('720x480')
        self.root.title('Image Display')
        
        # Open the image file and create a PIL image
        self.image = Image.open('image.jpg')
        
        # Create a Tkinter photo image from the PIL image
        self.photo_image = ImageTk.PhotoImage(self.image)
        
        # Create a label widget to display the image
        self.label = tk.Label(self.root, image=self.photo_image)
        self.label.pack(side=tk.LEFT, padx=1, pady=1)
        
        # Create a horizontal slider widget to adjust the threshold value
        self.slider = tk.Scale(self.root, from_=0, to=100, orient="vertical", resolution=0.1, length=300, command=self.update_threshold)
        self.slider.set(self.threshold)
        self.slider.pack(side=tk.LEFT, padx=1, pady=1)
        
        # Run the main loop
        self.root.mainloop()
        
    def update_threshold(self, val):
        self.threshold = float(val)
        print(self.threshold)
        
    def update_image_from_cv2(self, cv_image):
        cv_image = cv2.cvtColor(cv_image, cv2.COLOR_BGR2RGB)
        pil_image = Image.fromarray(image)
        
        # Create a Tkinter photo image from the thresholded image
        self.photo_image = ImageTk.PhotoImage(pil_image)
        
        # Update the photo image in the label widget
        self.label.config(image=self.photo_image)
        self.label.image = self.photo_image
        
    def set_threshold(self, val):
        print('test')
        
# Run the application
app = App()
# Out:
# 80.0
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2800.0_x64__qbz5n2kfra8p0\lib\tkinter\__init__.py", line 1921, in __call__
#     return self.func(*args)
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2800.0_x64__qbz5n2kfra8p0\lib\tkinter\__init__.py", line 839, in callit
#     func(*args)
# TypeError: App.update_image_from_cv2() missing 1 required positional argument: 'cv_image'
# 72.8
# 58.2
# 44.0
# 38.8
# 35.8
# 34.3
# 33.6
# 32.8
# 32.1
# 31.3
# 31.0
# 30.6
# 29.9
# 29.5
# 29.1
# 28.7
# 28.4
# 27.2
# 26.5
# 25.7
# 25.0
# 24.3
# 23.5
# 23.1
# 22.8
# 22.0
# 21.6
# 21.3
# 20.9
# 20.5
# 20.1
# 19.8
# 19.0
# 18.7
# 18.3
# 17.9
# 18.3
# 18.7
# 19.0
# 19.4
# 20.1
# 20.9
# 21.3
# 22.0
# 22.8
# 23.5
# 24.6
# 25.4
# 26.1
# 26.5
# 27.2
# 28.4
# 29.1
# 30.2
# 31.0
# 31.7
# 32.1
# 32.5
# 33.2
# 33.6
# 34.0
# 34.7
# 35.4
# 35.8
# 36.6
# 36.9
# 37.7
# ...

# %% [markdown]
# ### change opencv image to pil image

# %%
import cv2
from PIL import Image

# Read an image with OpenCV
image = cv2.imread('image.jpg')

# Convert the image to RGB format
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Convert the OpenCV image to a PIL image
pil_image = Image.fromarray(image)
